# %%
import numpy as np
from sklearn import preprocessing
from sklearn import model_selection
training=np.loadtxt('0000000000002419_training_ccpp_x_y_train.csv', delimiter=',')
testing=np.loadtxt('0000000000002419_test_ccpp_x_test.csv', delimiter=',')

# %%
def step_gradient(X, Y, m, learning_rate):
    m_slope=np.zeros(len(X[0]))
    for i in range(len(X)):
        x=X[i]
        y=Y[i]
        for j in range(len(x)):
            m_slope[j]+=(-2/len(X))*(y-sum(m*x))*x[j]
    new_m=m-(learning_rate*m_slope)
    return new_m

def cost(m, x, y):
    cost=0
    for i in range(len(x)):
        cost+=(1/len(x))*((y[i]-sum(m*x[i]))**2)
    print(cost)

def gd(x, y, learning_rate, iterations):
    m=np.zeros(len(x[0]))
    for i in range(iterations):
        m=step_gradient(x, y, m, learning_rate)
        print("itr= ", i, "cost=", end=' ')
        cost(m, x, y)
    return m

def gradient_descent(x, y):
    iterations=20000
    learning_rate=0.11
    x=np.append(x, np.ones(len(x)).reshape(-1, 1), axis=1)
    m=gd(x, y, learning_rate, iterations)
    return m

# %%
x=training[:, :-1]
y=training[:, -1]

#adding squared values of each column

sq=[]
for i in range(len(x[0])):
    for j in range(i, len(x[0])):
        sq.append(x[:, i]*x[:, j])
sq=np.array(sq)
for i in sq:
    x=np.append(x, i.reshape(-1, 1), axis=1)
    
#scaling

scaler=preprocessing.StandardScaler()
scaler.fit(x)
x=scaler.transform(x)
m=gradient_descent(x, y)
# Out:
# itr=  0 cost= 125879.92574696324
# itr=  1 cost= 76638.13554298022
# itr=  2 cost= 46671.123474268665
# itr=  3 cost= 28432.390748094847
# itr=  4 cost= 17330.416021778357
# itr=  5 cost= 10571.48220960588
# itr=  6 cost= 6455.697233621184
# itr=  7 cost= 3948.688381504386
# itr=  8 cost= 2421.0146256612534
# itr=  9 cost= 1489.6195505027652
# itr=  10 cost= 921.3667870632304
# itr=  11 cost= 574.3472833404326
# itr=  12 cost= 362.16764774747656
# itr=  13 cost= 232.22073948125092
# itr=  14 cost= 152.4635156570888
# itr=  15 cost= 103.37106571195326
# itr=  16 cost= 73.04014061723014
# itr=  17 cost= 54.20908039516801
# itr=  18 cost= 42.443877828980476
# itr=  19 cost= 35.033881366025796
# itr=  20 cost= 30.319373957949832
# itr=  21 cost= 27.282011924903042
# itr=  22 cost= 25.29527447214519
# itr=  23 cost= 23.972333993211624
# itr=  24 cost= 23.073254247895914
# itr=  25 cost= 22.448329942830387
# itr=  26 cost= 22.003452343602095
# itr=  27 cost= 21.67890604759899
# ...

# %%
	
x.shape
# Out:
# (7176, 14)

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Generate polynomial features for training data
sq_train = []
for i in range(len(X_train[0])):
    for j in range(i, len(X_train[0])):
        sq_train.append(X_train[:, i] * X_train[:, j])

sq_train = np.array(sq_train)
for i in sq_train:
    X_train = np.append(X_train, i.reshape(-1, 1), axis=1)

# Fit StandardScaler on the training data AFTER generating polynomial features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Generate polynomial features for test data (same process as for training)
sq_test = []
for i in range(len(testing[0])):
    for j in range(i, len(testing[0])):
        sq_test.append(testing[:, i] * testing[:, j])

sq_test = np.array(sq_test)
for i in sq_test:
    testing = np.append(testing, i.reshape(-1, 1), axis=1)

# Transform the test data using the same scaler
testing_scaled = scaler.transform(testing)

# Add bias term (column of ones) to the test data
x_test = np.append(testing_scaled, np.ones(len(testing_scaled)).reshape(-1, 1), axis=1)

# Make predictions using the learned weights (theta)
ans = []
for i in x_test:
    ans.append(sum(i * m))  # 'm' is the weights learned from gradient descent

# Convert predictions to numpy array and save to CSV
ans = np.array(ans)
np.savetxt(fname='dataa_power_plant.csv', X=ans, delimiter=',', fmt='%.5f')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 # Generate polynomial features for training data
#       5 sq_train = []
# ----> 6 for i in range(len(X_train[0])):
#       7     for j in range(i, len(X_train[0])):
#       8         sq_train.append(X_train[:, i] * X_train[:, j])
#
# NameError: name 'X_train' is not defined
